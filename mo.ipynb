# %% [markdown]
# <a href="https://colab.research.google.com/github/nimotherb/Project-01/blob/main/mo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile app.py
import streamlit as st

# === 設定與 CSS ===
st.set_page_config(page_title='Project 靈驗', page_icon='⛩️', layout='wide')
st.markdown("""
<style>
.stApp {background-color: #0E1117; color: #00FF41; font-family: 'Courier New';}
[data-testid="stSidebar"] {background-color: #161B22;}
h1, h2, h3 {color: #E0E0E0 !important; text-shadow: 0 0 10px #00FF41;}
div[data-testid="stMetricValue"] {color: #00FF41;}
</style>
""", unsafe_allow_html=True)

# === 側邊欄 ===
st.sidebar.title('🎛️ 環境參數模擬')
rainfall = st.sidebar.slider('🌧️ 降雨量 (mm)', 0, 500, 20)
wind = st.sidebar.slider('💨 風速 (m/s)', 0, 60, 5)
pest = st.sidebar.slider('🐛 病蟲害指數', 0, 10, 1)

# === 核心邏輯 ===
risk_score = (rainfall * 0.2) + (wind * 0.5) + (pest * 10)
if risk_score > 100: risk_score = 100

# === 主畫面 ===
st.title('⛩️ Project 靈驗：天巡者戰情中心')
col1, col2, col3 = st.columns(3)
col1.metric("🌧️ 降雨", f"{rainfall}")
col2.metric("💨 風速", f"{wind}")
col3.metric("⚡ 風險", f"{int(risk_score)}")

if risk_score < 60:
    st.success('✅ M.O. 系統狀態：ONLINE (安全)')
    st.image("https://img.icons8.com/color/96/tea.png", width=60)
else:
    st.error('🚨 警告：天巡者防禦系統啟動！')
    st.image("https://img.icons8.com/color/96/drone.png", width=60)
# Out:
# Overwriting app.py

# %%
# 安裝 Streamlit 與 Cloudflare Tunnel 工具
# !pip install -q streamlit
# !wget -q -O cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared
print("✅ Streamlit 和 Cloudflare Tunnel 已安裝完畢！")
# Out:
# ✅ Streamlit 和 Cloudflare Tunnel 已安裝完畢！

# %%
# 1. 先殺掉所有舊的程序 (確保乾淨)
# !pkill cloudflared
# !pkill streamlit

# 2. 啟動通道，並把網址寫進紀錄檔 (這樣絕對找得到)
# !nohup ./cloudflared tunnel --url http://localhost:8501 > tunnel.log 2>&1 &

# 3. 等待 5 秒，然後暴力印出網址
import time
print("⏳ 正在挖出網址，請倒數 5 秒...")
time.sleep(5)
print("🎯 找到了！就是下面這個連結 (點它)：")
# !grep -o 'https://.*\.trycloudflare.com' tunnel.log

# 4. 啟動 App
# !streamlit run app.py
# Out:
# ⏳ 正在挖出網址，請倒數 5 秒...
# 🎯 找到了！就是下面這個連結 (點它)：
# https://part-revolutionary-introductory-collectibles.trycloudflare.com
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.127.14.80:8501
#
#   Stopping...
